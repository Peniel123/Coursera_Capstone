# %% [markdown]
# <a href="https://colab.research.google.com/github/Peniel123/Coursera_Capstone/blob/master/Capstone_Week_3_3_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### We begin by importing various libraries

# %%
import pandas as pd # library for data analsysis

# %% [markdown]
# ### We extract the table using pandas library

# %%
canada_postal_codes=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")[0]
canada_postal_codes
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M1A  ...                                       Not assigned
# 1           M2A  ...                                       Not assigned
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# ..          ...  ...                                                ...
# 175         M5Z  ...                                       Not assigned
# 176         M6Z  ...                                       Not assigned
# 177         M7Z  ...                                       Not assigned
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
# 179         M9Z  ...                                       Not assigned
#
# [180 rows x 3 columns]

# %% [markdown]
# ### Variuos postal codes are not assigned so we remove them

# %%
indexNames = canada_postal_codes[ canada_postal_codes['Borough'] == 'Not assigned' ].index
canada_postal_codes.drop(indexNames , inplace=True)
canada_postal_codes
# Out:
#     Postal Code  ...                                      Neighbourhood
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# 5           M6A  ...                   Lawrence Manor, Lawrence Heights
# 6           M7A  ...        Queen's Park, Ontario Provincial Government
# ..          ...  ...                                                ...
# 160         M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 165         M4Y  ...                               Church and Wellesley
# 168         M7Y  ...  Business reply mail Processing Centre, South C...
# 169         M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
canada_postal_codes.shape
# Out:
# (103, 3)

# %%
csv_file = 'https://cocl.us/Geospatial_data'
geo_coordinates = pd.read_csv(csv_file)
geo_coordinates
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
result = pd.merge(canada_postal_codes, geo_coordinates, how='left', on='Postal Code')
result
# Out:
#     Postal Code           Borough  ...   Latitude  Longitude
# 0           M3A        North York  ...  43.753259 -79.329656
# 1           M4A        North York  ...  43.725882 -79.315572
# 2           M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3           M6A        North York  ...  43.718518 -79.464763
# 4           M7A  Downtown Toronto  ...  43.662301 -79.389494
# ..          ...               ...  ...        ...        ...
# 98          M8X         Etobicoke  ...  43.653654 -79.506944
# 99          M4Y  Downtown Toronto  ...  43.665860 -79.383160
# 100         M7Y      East Toronto  ...  43.662744 -79.321558
# 101         M8Y         Etobicoke  ...  43.636258 -79.498509
# 102         M8Z         Etobicoke  ...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
# !conda install -c conda-forge geopy --yes 

from geopy.geocoders import Nominatim

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium

print('Libraries imported.')
# Out:
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# Libraries imported.

# %%
address = 'Toronto, TO'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.65238435, -79.38356765.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighbourhood in zip(result['Latitude'], result['Longitude'], result['Borough'], result['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
downtown_toronto_data = result[result['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
downtown_toronto_data.head()
# Out:
#   Postal Code           Borough  ...   Latitude  Longitude
# 0         M5A  Downtown Toronto  ...  43.654260 -79.360636
# 1         M7A  Downtown Toronto  ...  43.662301 -79.389494
# 2         M5B  Downtown Toronto  ...  43.657162 -79.378937
# 3         M5C  Downtown Toronto  ...  43.651494 -79.375418
# 4         M5E  Downtown Toronto  ...  43.644771 -79.373306
#
# [5 rows x 5 columns]

# %%
address = 'Downtown Toronto, TO'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6563221, -79.3809161.

# %%
# create map of Downtown Toronto using latitude and longitude values
map_downtown_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(downtown_toronto_data['Latitude'], downtown_toronto_data['Longitude'], downtown_toronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_downtown_toronto)  
    
map_downtown_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'LXXKR1CE4DOCORQHGNIEHPRXUNZEX3KEMPPWOVXBEKBBHQZA' # your Foursquare ID
CLIENT_SECRET = 'SIHJ0FBIFWHVGDM11OOD33FPTHPPKRCGDZLW5MSZCDF43J33' # your Foursquare Secret
VERSION = '201201010'
LIMIT = 30

# %%
# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

! pip install folium==0.5.0
import folium # plotting library

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
# Out:
# ...
#      |████████████████████████████████| 81kB 4.1MB/s
# ...
#   Created wheel for folium: filename=folium-0.5.0-cp36-none-any.whl size=76240 sha256=65df88fdad56fd4ec931e6a873fcb2d156709048b3709aaa42dbceb57a675807
#   Stored in directory: /root/.cache/pip/wheels/f8/98/ff/954791afc47740d554f0d9e5885fa09dd60c2265d42578e665
# Successfully built folium
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.5.0 which is incompatible.
# ...
#   Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# ...

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6534817, -79.3839347.

# %%
search_query = 'Train station'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Train station .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=LXXKR1CE4DOCORQHGNIEHPRXUNZEX3KEMPPWOVXBEKBBHQZA&client_secret=SIHJ0FBIFWHVGDM11OOD33FPTHPPKRCGDZLW5MSZCDF43J33&ll=43.6534817,-79.3839347&v=201201010&query=Train station&radius=2000&limit=30'

# %%
import requests # library to handle requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fae5a223a1e82333e265b4f'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'primary': True,
#       'shortName': 'Residential'}],
#     'hasPerk': False,
#     'id': '4b85f094f964a5209c7a31e3',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 570,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653886,
#        'lng': -79.391}],
#      'lat': 43.653886,
#      'lng': -79.391},
#     'name': '105 mccaul st (The Train Station)',
#     'referralId': 'v-1605261858'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id  ... location.state
# 0  4b85f094f964a5209c7a31e3  ...            NaN
# 1  4ad94f83f964a520b91921e3  ...             ON
# 2  4afddfd3f964a520a72b22e3  ...             ON
# 3  4ae225b4f964a520348b21e3  ...        Ontario
# 4  4bb75da746d4a5934e5bc7c0  ...             ON
#
# [5 rows x 18 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                              name  ...                        id
# 0               105 mccaul st (The Train Station)  ...  4b85f094f964a5209c7a31e3
# 1                                   Union Station  ...  4ad94f83f964a520b91921e3
# 2                       GO Train - Lakeshore West  ...  4afddfd3f964a520a72b22e3
# 3                       GO Train - Lakeshore East  ...  4ae225b4f964a520348b21e3
# 4                                  Via Rail Train  ...  4bb75da746d4a5934e5bc7c0
# 5                               GO Train - Barrie  ...  4b85ae7ff964a5207e6c31e3
# 6                               Go Train - Milton  ...  4c4f51fc24edc9b6b4ac7dbb
# 7                       Sherbourne Subway Station  ...  4ad7afb7f964a520ac0d21e3
# 8                                        Train 60  ...  5ad9c2af4c954c0cf9bde41b
# 9                          Toronto EMS Station 40  ...  4e305933b61c88c3a7a1bbab
# 10                     Train 646 Toronto - Ottawa  ...  5e2dfeb667b6f40007e6410b
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Toronto

# add a red circle marker to represent the Toronto
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Train stations as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Paris'

geolocator = Nominatim(user_agent="paris_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Paris are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Paris are 48.8566969, 2.3514616.

# %%
search_query = 'Train station'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Train station .... OK!

# %%
url2 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=LXXKR1CE4DOCORQHGNIEHPRXUNZEX3KEMPPWOVXBEKBBHQZA&client_secret=SIHJ0FBIFWHVGDM11OOD33FPTHPPKRCGDZLW5MSZCDF43J33&ll=48.8566969,2.3514616&v=201201010&query=Train station&radius=2000&limit=30'

# %%
import requests # library to handle requests
results2 = requests.get(url2).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5fae5a6bd91d7d1d49d8c06e'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '5c74122327cbd1002556f4bc',
#     'location': {'cc': 'FR',
#      'city': 'Paris',
#      'country': 'France',
#      'distance': 1005,
#      'formattedAddress': ['75005 Paris', 'France'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.847874,
#        'lng': 2.348501}],
#      'lat': 48.847874,
#      'lng': 2.348501,
#      'postalCode': '75005',
#      'state': 'Île-de-France'},
#     'name': 'Menton Train Station',
#     'referralId': 'v-1605261931'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results2['response']['venues']

# tranform venues into a dataframe
df = json_normalize(venues)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id  ... venuePage.id
# 0  5c74122327cbd1002556f4bc  ...          NaN
# 1  4b0ed281f964a5208e5b23e3  ...          NaN
# 2  5bad25e246e1b6002cf0a876  ...          NaN
# 3  4ba57a7df964a520320b39e3  ...          NaN
# 4  50be034ee4b0dabe802ac3c2  ...          NaN
#
# [5 rows x 18 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
dataframe_filtered2 = df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered2['categories'] = dataframe_filtered2.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered2.columns = [column.split('.')[-1] for column in dataframe_filtered2.columns]

dataframe_filtered2
# Out:
#                                                  name  ...                        id
# 0                                Menton Train Station  ...  5c74122327cbd1002556f4bc
# 1                                La Station Rambuteau  ...  4b0ed281f964a5208e5b23e3
# 2   Station de gonflage et de réparation vélos en ...  ...  5bad25e246e1b6002cf0a876
# 3                       Gare SNCF de Paris Austerlitz  ...  4ba57a7df964a520320b39e3
# 4                                    Autolib' Station  ...  50be034ee4b0dabe802ac3c2
# 5                                        Trainline EU  ...  4fe9fa8ee4b056ae91e80b9d
# 6                   RER Châtelet – Les Halles [A,B,D]  ...  4b6ef01bf964a5200fd22ce3
# 7                                    Autolib' Station  ...  5000096f90e7a1840b334d94
# 8                                    Autolib' Station  ...  50f3f44b45b0d6634cfaa37f
# 9                                    Autolib' Station  ...  4ef47de8771621805819d27b
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Paris

# add a red circle marker to represent the Paris
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Paris',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Train stations as blue circle markers
for lat, lng, label in zip(dataframe_filtered2.lat, dataframe_filtered2.lng, dataframe_filtered2.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Paris'

geolocator = Nominatim(user_agent="paris_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Paris are {}, {}.'.format(latitude, longitude))

# %%
search_query = 'Residential Area'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Residential Area .... OK!

# %%
url3 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url3
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=LXXKR1CE4DOCORQHGNIEHPRXUNZEX3KEMPPWOVXBEKBBHQZA&client_secret=SIHJ0FBIFWHVGDM11OOD33FPTHPPKRCGDZLW5MSZCDF43J33&ll=48.8566969,2.3514616&v=201201010&query=Residential Area&radius=2000&limit=30'

# %%
import requests # library to handle requests
results3 = requests.get(url3).json()
results3
# Out:
# {'meta': {'code': 200, 'requestId': '5fae5fe13e071546b354e0c3'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'primary': True,
#       'shortName': 'Art Gallery'}],
#     'hasPerk': False,
#     'id': '4ccc473faa25a35d9fa5130f',
#     'location': {'address': "50 rue d'Hauteville",
#      'cc': 'FR',
#      'city': 'Paris',
#      'country': 'France',
#      'distance': 1913,
#      'formattedAddress': ["50 rue d'Hauteville", '75010 Paris', 'France'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87387682932462,
#        'lng': 2.3505461430017194}],
#      'lat': 48.87387682932462,
#      'lng': 2.3505461430017194,
#      'postalCode': '75010',
#      'state': 'Île-de-France'},
#     'name': 'Galerie Area, La réserve',
# ...

# %%
# assign relevant part of JSON to venues
venues3 = results3['response']['venues']

# tranform venues into a dataframe
dataframe3 = json_normalize(venues3)


# keep only columns that include venue name, and anything that is associated with location
filtered_columns3 = ['name', 'categories'] + [col for col in dataframe3.columns if col.startswith('location.')] + ['id']
dataframe_filtered3 = dataframe3.loc[:, filtered_columns3]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered3['categories'] = dataframe_filtered3.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered3.columns = [column.split('.')[-1] for column in dataframe_filtered3.columns]

dataframe_filtered3
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                                  name  ...                        id
# 0            Galerie Area, La réserve  ...  4ccc473faa25a35d9fa5130f
# 1                            Area Box  ...  50ebe47ae4b019b196f02d66
# 2    Hôtel Marais HÔme area bien-être  ...  542872bc498e259fb73ec8b7
# 3                         L'Area Café  ...  4b8121a8f964a520d29730e3
# 4                           Grey Area  ...  51a7908e498eaaf625d1a7c2
# 5                              L'Area  ...  52190fac11d29ec03ac72d5d
# 6  Aréas Assurances Stanislas LEVCHIN  ...  5cee8a9a2db4a9002c55708d
# 7  Aréas Assurances Christophe CHIRON  ...  5cee89eeb9b37b002c63688b
#
# [8 rows x 15 columns]

# %%
dataframe_filtered3.shape
# Out:
# (8, 15)
